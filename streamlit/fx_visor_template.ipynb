# %% [markdown]
# # `FX Visor` Experiments Notebook

# %% [markdown]
# ## Prerelease

# %%
import yaml

with open("config.yaml","r") as configfile:
    cfg=yaml.safe_load(configfile)

# %%
cfg.keys()
# Out:
# dict_keys(['currencies'])

# %%
cfg["currencies"]["G11"]
# Out:
# ['AUD', 'CAD', 'JPY', 'NZD', 'NOK', 'GBP', 'SEK', 'CHF', 'USD', 'DKK']

# %%
tickers = ["EUR"+currency+"=X" for currency in cfg["currencies"]["G11"]]

# %%
tickers
# Out:
# ['EURAUD=X',
#  'EURCAD=X',
#  'EURJPY=X',
#  'EURNZD=X',
#  'EURNOK=X',
#  'EURGBP=X',
#  'EURSEK=X',
#  'EURCHF=X',
#  'EURUSD=X',
#  'EURDKK=X']

# %%
import yfinance as yf
import matplotlib.pyplot as plt

fx_prices = 1/yf.download(tickers)["Close"].dropna(how="any")
# Out:
# [*********************100%***********************]  10 of 10 completed

# %%
fx_prices.index[0]
# Out:
# Timestamp('2003-12-01 00:00:00')

# %%
fx_prices.index[-1]
# Out:
# Timestamp('2022-11-21 00:00:00')

# %%
(fx_prices/fx_prices.iloc[0,:]).plot(figsize=(21,9))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
fx_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4916 entries, 2003-12-01 to 2022-11-18
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   EURAUD=X  4916 non-null   float64
#  1   EURCAD=X  4916 non-null   float64
#  2   EURCHF=X  4916 non-null   float64
#  3   EURDKK=X  4916 non-null   float64
#  4   EURGBP=X  4916 non-null   float64
#  5   EURJPY=X  4916 non-null   float64
#  6   EURNOK=X  4916 non-null   float64
#  7   EURNZD=X  4916 non-null   float64
#  8   EURSEK=X  4916 non-null   float64
#  9   EURUSD=X  4916 non-null   float64
# dtypes: float64(10)
# memory usage: 422.5 KB

# %%
import time

time.strftime(fx_prices.index[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/hcf/source/Python/fx_letor/streamlit/fx_visor_template.ipynb Celda 11 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/home/hcf/source/Python/fx_letor/streamlit/fx_visor_template.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> import time
# ----> <a href='vscode-notebook-cell:/home/hcf/source/Python/fx_letor/streamlit/fx_visor_template.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> time.strftime(fx_prices.index[0])
#
# TypeError: strftime() argument 1 must be str, not Timestamp

# %%
ts = fx_prices.index[0]

# %%
ts.strftime("%Y-%m-%d")
# Out:
# '20031201'

# %% [markdown]
# ## Extending to more Currencies

# %%
import yaml

# %%
PATH_STREAMLIT_APP = "/app/fx_letor/streamlit/"
CONFIG_FILE = "config.yaml"
FULLPATH_CONFIG_FILE = PATH_STREAMLIT_APP + CONFIG_FILE

# %%
try:
    with open(FULLPATH_CONFIG_FILE,"r") as configfile:
        cfg=yaml.safe_load(configfile)
except:
    with open(CONFIG_FILE,"r") as configfile:
        cfg=yaml.safe_load(configfile)

# %%
cfg["currencies"].keys()
# Out:
# dict_keys(['G11', 'CEEMEA', 'Africa', 'EM_Asia', 'EM_Latam'])

# %%
curncy = list()

curncy.extend(["AAPL","GOOG"])

# %%
curncy
# Out:
# ['AAPL', 'GOOG']

# %%
for countries in cfg["currencies"].keys():
    print(cfg["currencies"][countries])
# Out:
# ['AUD', 'CAD', 'JPY', 'NZD', 'NOK', 'GBP', 'SEK', 'CHF', 'USD', 'DKK']
# ['RUB', 'TRY']
# ['ZAR']
# ['HKD', 'INR', 'SGD', 'TWD']
# ['BRL', 'MXN']

# %%
blocks = cfg["currencies"].keys()
for country in blocks:
    curncy.extend(cfg["currencies"][country])

# %%
curncy
# Out:
# ['AAPL',
#  'GOOG',
#  'AUD',
#  'CAD',
#  'JPY',
#  'NZD',
#  'NOK',
#  'GBP',
#  'SEK',
#  'CHF',
#  'USD',
#  'DKK',
#  'RUB',
#  'TRY',
#  'ZAR',
#  'HKD',
#  'INR',
#  'SGD',
#  'TWD',
#  'BRL',
#  'MXN']

# %%
import yfinance as yf
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2003-12-01  35.740002  35.779999  35.316002  35.509998  35.509998       0
# 2003-12-02  35.509998  35.939999  35.375999  35.880001  35.880001       0
# 2003-12-03  35.889999  36.000000  35.709999  35.980000  35.980000       0
# 2003-12-04  35.959999  36.029999  35.625000  35.840000  35.840000       0
# 2003-12-05  35.840000  36.080002  35.617001  36.080002  36.080002       0

# %%
yf.download("EURINR=X").head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#               Open    High     Low   Close  Adj Close  Volume
# Date
# 2003-12-01  2.0727  2.0745  2.0572  2.0592     2.0592       0
# 2003-12-02  2.0602  2.0822  2.0555  2.0786     2.0786       0
# 2003-12-03  2.0784  2.0827  2.0729  2.0796     2.0796       0
# 2003-12-04  2.0798  2.0807  2.0630  2.0687     2.0687       0
# 2003-12-05  2.0694  2.0879  2.0692  2.0872     2.0872       0
